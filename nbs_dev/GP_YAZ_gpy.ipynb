# %%
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import pandas as pd
import numpy as np
from scipy.stats import norm
from gp_dev.core import *
from ddop.datasets import load_yaz
from pathlib import Path
import datetime
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = Path("..")
path_ds = path/'datasets'
path_res = path/'res_data'
path_plot = path/'plots'

# %%
res = []

for target in ['CALAMARI', 'FISH', 'SHRIMP', 'CHICKEN', 'KOEFTE', 'LAMB', 'STEAK']:
#for target in ['STEAK']:

    #df = load_yaz(encode_date_features=True, include_prod=[target]).frame
    #df = df[[x for x in df.columns if not x.startswith('YEAR')]]
    
    products = [target]
    df = load_yaz(encode_date_features=True, include_prod=products, include_date=True).frame
    df['DEMAND_DATE'] = pd.to_datetime(df['DEMAND_DATE'])
    df['DEMAND_DATE'] = (df['DEMAND_DATE'] - datetime.datetime(1970,1,1)).astype('timedelta64[D]').values
    df = df[['DEMAND_DATE',target]]
    
    scaler = MinMaxScaler()
    df_scaled = scaler.fit_transform(df)
    data = torch.tensor(df_scaled, dtype=torch.float32)

    N = data.shape[0]
    # make train/val/test
    #n_train = int(0.8 * N)
    n_train = 600 #
    #n_train = int(1 * N)
    train_x, train_y = data[:n_train, :-1], data[:n_train, -1]
    test_x, test_y = data[n_train:, :-1], data[n_train:, -1]

    # make continguous
    train_x, train_y = train_x.contiguous(), train_y.contiguous()
    test_x, test_y = test_x.contiguous(), test_y.contiguous()

    output_device = torch.device('cuda:0')

    train_x, train_y = train_x.to(output_device), train_y.to(output_device)
    test_x, test_y = test_x.to(output_device), test_y.to(output_device)

    n_devices = torch.cuda.device_count()
    print('Planning to run on {} GPUs.'.format(n_devices))

    # initialize likelihood and model
    likelihood = gpytorch.likelihoods.GaussianLikelihood().cuda()
    model = ExactGPModel(train_x, train_y, likelihood).cuda()

    # Find optimal model hyperparameters
    model.train()
    likelihood.train()
    training_iter=100

    # Use the adam optimizer
    optimizer = torch.optim.Adam([
        {'params': model.parameters()},  # Includes GaussianLikelihood parameters
    ], lr=0.1)

    # "Loss" for GPs - the marginal log likelihood
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for i in range(training_iter):
        # Zero gradients from previous iteration
        optimizer.zero_grad()
        # Output from model
        output = model(train_x)
        # Calc loss and backprop gradients
        loss = -mll(output, train_y)
        loss.backward()
        print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
            i + 1, training_iter, loss.item(),
            model.covar_module.base_kernel.lengthscale.item(),
            model.likelihood.noise.item()
        ))
        optimizer.step()
    model.eval()
    likelihood.eval()

    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        observed_pred = likelihood(model(test_x))
        #observed_pred_train = likelihood(model(train_x))

    ## NV

    #y_train_unscaled = scaler.inverse_transform(df[n_train:,:])[:,-1]
    y_train_unscaled = scaler.inverse_transform(df_scaled[:n_train,:])[:,-1]
    y_test_unscaled = scaler.inverse_transform(df_scaled[n_train:,:])[:,-1]

    n_features = df_scaled.shape[1]
    nv_means = observed_pred.mean.cpu().numpy()
    #nv_means = observed_pred_train.mean.cpu().numpy()
    nv_means_unscaled = scaler.inverse_transform(np.stack([nv_means for i in range(n_features)], axis=1))[:,-1]

    #nv_sigma = np.sqrt(torch.diag(observed_pred.covariance_matrix).cpu().detach().numpy())
    four_sigma = observed_pred.confidence_region()[1]-observed_pred.confidence_region()[0]
    nv_sigma = four_sigma.cpu().detach().numpy()/4.
    #nv_sigma = np.sqrt(torch.diag(observed_pred_train.covariance_matrix).cpu().detach().numpy())
    nv_sigma_unscaled = scaler.inverse_transform(np.stack([nv_sigma for i in range(n_features)], axis=1))[:,-1]
    
    for c in range(5,100, 5):
        cu = c/100
        co = 1-cu
        nv_quantile = np.quantile(y_train_unscaled, q=cu/(cu+co))
        nv_solution = nv_means_unscaled+norm.ppf(cu/(cu+co))*nv_sigma_unscaled
        cost_saa = np.mean([nv_cost(nv_quantile, y, cu, co) for y in y_test_unscaled])
        cost_gp =  np.mean([nv_cost(q, y, cu, co) for q, y in zip(nv_solution, y_test_unscaled)])
        ser_tmp=pd.Series({"cu":cu, "co":co, "cost":cost_saa, "type":"saa", "target": target})
        res.append(ser_tmp)
        ser_tmp=pd.Series({"cu":cu, "co":co, "cost":cost_gp, "type":"gp", "target": target})
        res.append(ser_tmp)
df_res = pd.DataFrame(res)
#df_res.to_csv(path/'res_data'/'gp_all.csv', index=False)
# Out:
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.771   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.735   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.698   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.660   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.622   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.583   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.543   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.503   lengthscale: 1.098   noise: 0.403
# Iter 9/100 - Loss: 0.462   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.421   lengthscale: 1.230   noise: 0.340
# Iter 11/100 - Loss: 0.380   lengthscale: 1.298   noise: 0.312
# Iter 12/100 - Loss: 0.338   lengthscale: 1.367   noise: 0.286
# Iter 13/100 - Loss: 0.295   lengthscale: 1.437   noise: 0.262
# Iter 14/100 - Loss: 0.252   lengthscale: 1.507   noise: 0.239
# Iter 15/100 - Loss: 0.209   lengthscale: 1.578   noise: 0.218
# Iter 16/100 - Loss: 0.166   lengthscale: 1.649   noise: 0.199
# Iter 17/100 - Loss: 0.123   lengthscale: 1.721   noise: 0.181
# Iter 18/100 - Loss: 0.079   lengthscale: 1.792   noise: 0.165
# Iter 19/100 - Loss: 0.036   lengthscale: 1.864   noise: 0.150
# Iter 20/100 - Loss: -0.007   lengthscale: 1.935   noise: 0.136
# Iter 21/100 - Loss: -0.051   lengthscale: 2.006   noise: 0.124
# Iter 22/100 - Loss: -0.094   lengthscale: 2.076   noise: 0.113
# Iter 23/100 - Loss: -0.137   lengthscale: 2.145   noise: 0.102
# Iter 24/100 - Loss: -0.179   lengthscale: 2.214   noise: 0.093
# Iter 25/100 - Loss: -0.221   lengthscale: 2.280   noise: 0.084
# Iter 26/100 - Loss: -0.262   lengthscale: 2.346   noise: 0.076
# Iter 27/100 - Loss: -0.302   lengthscale: 2.409   noise: 0.069
# Iter 28/100 - Loss: -0.341   lengthscale: 2.471   noise: 0.063
# Iter 29/100 - Loss: -0.378   lengthscale: 2.530   noise: 0.057
# Iter 30/100 - Loss: -0.415   lengthscale: 2.587   noise: 0.052
# Iter 31/100 - Loss: -0.450   lengthscale: 2.643   noise: 0.047
# Iter 32/100 - Loss: -0.483   lengthscale: 2.696   noise: 0.043
# Iter 33/100 - Loss: -0.514   lengthscale: 2.747   noise: 0.039
# Iter 34/100 - Loss: -0.544   lengthscale: 2.795   noise: 0.035
# Iter 35/100 - Loss: -0.571   lengthscale: 2.842   noise: 0.032
# Iter 36/100 - Loss: -0.596   lengthscale: 2.887   noise: 0.029
# Iter 37/100 - Loss: -0.618   lengthscale: 2.929   noise: 0.027
# Iter 38/100 - Loss: -0.638   lengthscale: 2.970   noise: 0.025
# Iter 39/100 - Loss: -0.656   lengthscale: 3.009   noise: 0.023
# Iter 40/100 - Loss: -0.670   lengthscale: 3.046   noise: 0.021
# Iter 41/100 - Loss: -0.682   lengthscale: 3.081   noise: 0.019
# Iter 42/100 - Loss: -0.692   lengthscale: 3.115   noise: 0.018
# Iter 43/100 - Loss: -0.698   lengthscale: 3.147   noise: 0.017
# Iter 44/100 - Loss: -0.703   lengthscale: 3.177   noise: 0.016
# Iter 45/100 - Loss: -0.705   lengthscale: 3.206   noise: 0.015
# Iter 46/100 - Loss: -0.706   lengthscale: 3.233   noise: 0.014
# Iter 47/100 - Loss: -0.705   lengthscale: 3.259   noise: 0.013
# Iter 48/100 - Loss: -0.702   lengthscale: 3.283   noise: 0.013
# Iter 49/100 - Loss: -0.700   lengthscale: 3.306   noise: 0.012
# Iter 50/100 - Loss: -0.697   lengthscale: 3.328   noise: 0.012
# Iter 51/100 - Loss: -0.694   lengthscale: 3.348   noise: 0.011
# Iter 52/100 - Loss: -0.691   lengthscale: 3.367   noise: 0.011
# Iter 53/100 - Loss: -0.689   lengthscale: 3.384   noise: 0.011
# Iter 54/100 - Loss: -0.688   lengthscale: 3.401   noise: 0.011
# Iter 55/100 - Loss: -0.687   lengthscale: 3.416   noise: 0.011
# Iter 56/100 - Loss: -0.687   lengthscale: 3.430   noise: 0.011
# Iter 57/100 - Loss: -0.688   lengthscale: 3.442   noise: 0.011
# Iter 58/100 - Loss: -0.690   lengthscale: 3.454   noise: 0.011
# Iter 59/100 - Loss: -0.692   lengthscale: 3.464   noise: 0.011
# Iter 60/100 - Loss: -0.694   lengthscale: 3.474   noise: 0.011
# Iter 61/100 - Loss: -0.696   lengthscale: 3.483   noise: 0.011
# Iter 62/100 - Loss: -0.698   lengthscale: 3.490   noise: 0.012
# Iter 63/100 - Loss: -0.700   lengthscale: 3.497   noise: 0.012
# Iter 64/100 - Loss: -0.702   lengthscale: 3.502   noise: 0.012
# Iter 65/100 - Loss: -0.704   lengthscale: 3.507   noise: 0.013
# Iter 66/100 - Loss: -0.705   lengthscale: 3.512   noise: 0.013
# Iter 67/100 - Loss: -0.706   lengthscale: 3.515   noise: 0.013
# Iter 68/100 - Loss: -0.706   lengthscale: 3.518   noise: 0.013
# Iter 69/100 - Loss: -0.707   lengthscale: 3.520   noise: 0.014
# Iter 70/100 - Loss: -0.707   lengthscale: 3.521   noise: 0.014
# Iter 71/100 - Loss: -0.707   lengthscale: 3.522   noise: 0.014
# Iter 72/100 - Loss: -0.707   lengthscale: 3.522   noise: 0.014
# Iter 73/100 - Loss: -0.707   lengthscale: 3.522   noise: 0.015
# Iter 74/100 - Loss: -0.707   lengthscale: 3.521   noise: 0.015
# Iter 75/100 - Loss: -0.706   lengthscale: 3.520   noise: 0.015
# Iter 76/100 - Loss: -0.706   lengthscale: 3.518   noise: 0.015
# Iter 77/100 - Loss: -0.706   lengthscale: 3.516   noise: 0.015
# Iter 78/100 - Loss: -0.706   lengthscale: 3.513   noise: 0.015
# Iter 79/100 - Loss: -0.706   lengthscale: 3.510   noise: 0.015
# Iter 80/100 - Loss: -0.706   lengthscale: 3.506   noise: 0.015
# Iter 81/100 - Loss: -0.706   lengthscale: 3.503   noise: 0.015
# Iter 82/100 - Loss: -0.706   lengthscale: 3.498   noise: 0.015
# Iter 83/100 - Loss: -0.706   lengthscale: 3.494   noise: 0.015
# Iter 84/100 - Loss: -0.706   lengthscale: 3.489   noise: 0.015
# Iter 85/100 - Loss: -0.706   lengthscale: 3.484   noise: 0.015
# Iter 86/100 - Loss: -0.706   lengthscale: 3.478   noise: 0.015
# Iter 87/100 - Loss: -0.707   lengthscale: 3.472   noise: 0.015
# Iter 88/100 - Loss: -0.707   lengthscale: 3.466   noise: 0.015
# Iter 89/100 - Loss: -0.707   lengthscale: 3.459   noise: 0.015
# Iter 90/100 - Loss: -0.707   lengthscale: 3.453   noise: 0.015
# Iter 91/100 - Loss: -0.707   lengthscale: 3.446   noise: 0.014
# Iter 92/100 - Loss: -0.707   lengthscale: 3.438   noise: 0.014
# Iter 93/100 - Loss: -0.707   lengthscale: 3.431   noise: 0.014
# Iter 94/100 - Loss: -0.707   lengthscale: 3.423   noise: 0.014
# Iter 95/100 - Loss: -0.707   lengthscale: 3.415   noise: 0.014
# Iter 96/100 - Loss: -0.707   lengthscale: 3.406   noise: 0.014
# Iter 97/100 - Loss: -0.707   lengthscale: 3.398   noise: 0.014
# Iter 98/100 - Loss: -0.707   lengthscale: 3.389   noise: 0.014
# Iter 99/100 - Loss: -0.707   lengthscale: 3.380   noise: 0.014
# Iter 100/100 - Loss: -0.707   lengthscale: 3.371   noise: 0.014
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.780   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.744   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.708   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.671   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.634   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.596   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.558   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.519   lengthscale: 1.098   noise: 0.403
# Iter 9/100 - Loss: 0.480   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.440   lengthscale: 1.230   noise: 0.340
# Iter 11/100 - Loss: 0.400   lengthscale: 1.297   noise: 0.312
# Iter 12/100 - Loss: 0.360   lengthscale: 1.366   noise: 0.286
# Iter 13/100 - Loss: 0.320   lengthscale: 1.436   noise: 0.262
# Iter 14/100 - Loss: 0.279   lengthscale: 1.506   noise: 0.239
# Iter 15/100 - Loss: 0.239   lengthscale: 1.576   noise: 0.219
# Iter 16/100 - Loss: 0.199   lengthscale: 1.647   noise: 0.199
# Iter 17/100 - Loss: 0.159   lengthscale: 1.718   noise: 0.182
# Iter 18/100 - Loss: 0.119   lengthscale: 1.789   noise: 0.166
# Iter 19/100 - Loss: 0.080   lengthscale: 1.860   noise: 0.151
# Iter 20/100 - Loss: 0.042   lengthscale: 1.931   noise: 0.137
# Iter 21/100 - Loss: 0.004   lengthscale: 2.001   noise: 0.125
# Iter 22/100 - Loss: -0.033   lengthscale: 2.070   noise: 0.114
# Iter 23/100 - Loss: -0.069   lengthscale: 2.139   noise: 0.103
# Iter 24/100 - Loss: -0.104   lengthscale: 2.207   noise: 0.094
# Iter 25/100 - Loss: -0.137   lengthscale: 2.275   noise: 0.085
# Iter 26/100 - Loss: -0.169   lengthscale: 2.341   noise: 0.078
# Iter 27/100 - Loss: -0.199   lengthscale: 2.407   noise: 0.071
# Iter 28/100 - Loss: -0.227   lengthscale: 2.471   noise: 0.065
# Iter 29/100 - Loss: -0.253   lengthscale: 2.535   noise: 0.059
# Iter 30/100 - Loss: -0.277   lengthscale: 2.597   noise: 0.054
# Iter 31/100 - Loss: -0.298   lengthscale: 2.658   noise: 0.049
# Iter 32/100 - Loss: -0.317   lengthscale: 2.718   noise: 0.045
# Iter 33/100 - Loss: -0.333   lengthscale: 2.777   noise: 0.041
# Iter 34/100 - Loss: -0.346   lengthscale: 2.834   noise: 0.038
# Iter 35/100 - Loss: -0.357   lengthscale: 2.890   noise: 0.035
# Iter 36/100 - Loss: -0.365   lengthscale: 2.945   noise: 0.033
# Iter 37/100 - Loss: -0.370   lengthscale: 2.998   noise: 0.031
# Iter 38/100 - Loss: -0.374   lengthscale: 3.050   noise: 0.029
# Iter 39/100 - Loss: -0.375   lengthscale: 3.100   noise: 0.027
# Iter 40/100 - Loss: -0.374   lengthscale: 3.149   noise: 0.025
# Iter 41/100 - Loss: -0.372   lengthscale: 3.196   noise: 0.024
# Iter 42/100 - Loss: -0.370   lengthscale: 3.241   noise: 0.023
# Iter 43/100 - Loss: -0.366   lengthscale: 3.285   noise: 0.022
# Iter 44/100 - Loss: -0.363   lengthscale: 3.326   noise: 0.022
# Iter 45/100 - Loss: -0.361   lengthscale: 3.367   noise: 0.021
# Iter 46/100 - Loss: -0.358   lengthscale: 3.405   noise: 0.021
# Iter 47/100 - Loss: -0.357   lengthscale: 3.442   noise: 0.021
# Iter 48/100 - Loss: -0.357   lengthscale: 3.476   noise: 0.021
# Iter 49/100 - Loss: -0.357   lengthscale: 3.509   noise: 0.021
# Iter 50/100 - Loss: -0.358   lengthscale: 3.541   noise: 0.021
# Iter 51/100 - Loss: -0.360   lengthscale: 3.570   noise: 0.021
# Iter 52/100 - Loss: -0.362   lengthscale: 3.598   noise: 0.021
# Iter 53/100 - Loss: -0.365   lengthscale: 3.625   noise: 0.022
# Iter 54/100 - Loss: -0.368   lengthscale: 3.650   noise: 0.022
# Iter 55/100 - Loss: -0.372   lengthscale: 3.674   noise: 0.023
# Iter 56/100 - Loss: -0.375   lengthscale: 3.697   noise: 0.023
# Iter 57/100 - Loss: -0.378   lengthscale: 3.718   noise: 0.024
# Iter 58/100 - Loss: -0.380   lengthscale: 3.736   noise: 0.024
# Iter 59/100 - Loss: -0.382   lengthscale: 3.753   noise: 0.025
# Iter 60/100 - Loss: -0.383   lengthscale: 3.768   noise: 0.026
# Iter 61/100 - Loss: -0.383   lengthscale: 3.782   noise: 0.026
# Iter 62/100 - Loss: -0.383   lengthscale: 3.794   noise: 0.027
# Iter 63/100 - Loss: -0.383   lengthscale: 3.804   noise: 0.027
# Iter 64/100 - Loss: -0.383   lengthscale: 3.813   noise: 0.028
# Iter 65/100 - Loss: -0.383   lengthscale: 3.819   noise: 0.028
# Iter 66/100 - Loss: -0.383   lengthscale: 3.824   noise: 0.028
# Iter 67/100 - Loss: -0.382   lengthscale: 3.828   noise: 0.029
# Iter 68/100 - Loss: -0.382   lengthscale: 3.829   noise: 0.029
# Iter 69/100 - Loss: -0.382   lengthscale: 3.829   noise: 0.029
# Iter 70/100 - Loss: -0.381   lengthscale: 3.828   noise: 0.029
# Iter 71/100 - Loss: -0.381   lengthscale: 3.825   noise: 0.029
# Iter 72/100 - Loss: -0.381   lengthscale: 3.820   noise: 0.029
# Iter 73/100 - Loss: -0.381   lengthscale: 3.814   noise: 0.029
# Iter 74/100 - Loss: -0.381   lengthscale: 3.808   noise: 0.029
# Iter 75/100 - Loss: -0.382   lengthscale: 3.799   noise: 0.029
# Iter 76/100 - Loss: -0.382   lengthscale: 3.790   noise: 0.029
# Iter 77/100 - Loss: -0.382   lengthscale: 3.780   noise: 0.029
# Iter 78/100 - Loss: -0.382   lengthscale: 3.769   noise: 0.028
# Iter 79/100 - Loss: -0.382   lengthscale: 3.757   noise: 0.028
# Iter 80/100 - Loss: -0.383   lengthscale: 3.745   noise: 0.028
# Iter 81/100 - Loss: -0.383   lengthscale: 3.732   noise: 0.028
# Iter 82/100 - Loss: -0.383   lengthscale: 3.719   noise: 0.028
# Iter 83/100 - Loss: -0.383   lengthscale: 3.705   noise: 0.027
# Iter 84/100 - Loss: -0.383   lengthscale: 3.690   noise: 0.027
# Iter 85/100 - Loss: -0.383   lengthscale: 3.676   noise: 0.027
# Iter 86/100 - Loss: -0.383   lengthscale: 3.661   noise: 0.027
# Iter 87/100 - Loss: -0.384   lengthscale: 3.647   noise: 0.027
# Iter 88/100 - Loss: -0.384   lengthscale: 3.632   noise: 0.027
# Iter 89/100 - Loss: -0.384   lengthscale: 3.617   noise: 0.026
# Iter 90/100 - Loss: -0.384   lengthscale: 3.603   noise: 0.026
# Iter 91/100 - Loss: -0.383   lengthscale: 3.588   noise: 0.026
# Iter 92/100 - Loss: -0.383   lengthscale: 3.574   noise: 0.026
# Iter 93/100 - Loss: -0.383   lengthscale: 3.560   noise: 0.026
# Iter 94/100 - Loss: -0.383   lengthscale: 3.547   noise: 0.026
# Iter 95/100 - Loss: -0.383   lengthscale: 3.534   noise: 0.026
# Iter 96/100 - Loss: -0.383   lengthscale: 3.521   noise: 0.026
# Iter 97/100 - Loss: -0.383   lengthscale: 3.508   noise: 0.026
# Iter 98/100 - Loss: -0.383   lengthscale: 3.495   noise: 0.026
# Iter 99/100 - Loss: -0.384   lengthscale: 3.483   noise: 0.026
# Iter 100/100 - Loss: -0.384   lengthscale: 3.471   noise: 0.026
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.778   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.742   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.706   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.669   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.631   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.593   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.554   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.515   lengthscale: 1.097   noise: 0.403
# Iter 9/100 - Loss: 0.476   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.436   lengthscale: 1.229   noise: 0.340
# Iter 11/100 - Loss: 0.395   lengthscale: 1.297   noise: 0.312
# Iter 12/100 - Loss: 0.355   lengthscale: 1.366   noise: 0.286
# Iter 13/100 - Loss: 0.314   lengthscale: 1.435   noise: 0.262
# Iter 14/100 - Loss: 0.273   lengthscale: 1.505   noise: 0.239
# Iter 15/100 - Loss: 0.232   lengthscale: 1.576   noise: 0.218
# Iter 16/100 - Loss: 0.191   lengthscale: 1.646   noise: 0.199
# Iter 17/100 - Loss: 0.150   lengthscale: 1.717   noise: 0.182
# Iter 18/100 - Loss: 0.110   lengthscale: 1.788   noise: 0.166
# Iter 19/100 - Loss: 0.070   lengthscale: 1.859   noise: 0.151
# Iter 20/100 - Loss: 0.030   lengthscale: 1.929   noise: 0.137
# Iter 21/100 - Loss: -0.010   lengthscale: 2.000   noise: 0.125
# Iter 22/100 - Loss: -0.048   lengthscale: 2.069   noise: 0.113
# Iter 23/100 - Loss: -0.086   lengthscale: 2.138   noise: 0.103
# Iter 24/100 - Loss: -0.123   lengthscale: 2.206   noise: 0.094
# Iter 25/100 - Loss: -0.159   lengthscale: 2.271   noise: 0.085
# Iter 26/100 - Loss: -0.193   lengthscale: 2.335   noise: 0.077
# Iter 27/100 - Loss: -0.225   lengthscale: 2.397   noise: 0.070
# Iter 28/100 - Loss: -0.256   lengthscale: 2.456   noise: 0.064
# Iter 29/100 - Loss: -0.285   lengthscale: 2.512   noise: 0.058
# Iter 30/100 - Loss: -0.312   lengthscale: 2.566   noise: 0.053
# Iter 31/100 - Loss: -0.336   lengthscale: 2.616   noise: 0.049
# Iter 32/100 - Loss: -0.358   lengthscale: 2.664   noise: 0.044
# Iter 33/100 - Loss: -0.377   lengthscale: 2.708   noise: 0.041
# Iter 34/100 - Loss: -0.394   lengthscale: 2.749   noise: 0.037
# Iter 35/100 - Loss: -0.408   lengthscale: 2.786   noise: 0.034
# Iter 36/100 - Loss: -0.419   lengthscale: 2.820   noise: 0.032
# Iter 37/100 - Loss: -0.427   lengthscale: 2.850   noise: 0.029
# Iter 38/100 - Loss: -0.433   lengthscale: 2.877   noise: 0.027
# Iter 39/100 - Loss: -0.436   lengthscale: 2.900   noise: 0.026
# Iter 40/100 - Loss: -0.437   lengthscale: 2.920   noise: 0.024
# Iter 41/100 - Loss: -0.437   lengthscale: 2.936   noise: 0.023
# Iter 42/100 - Loss: -0.435   lengthscale: 2.949   noise: 0.022
# Iter 43/100 - Loss: -0.432   lengthscale: 2.959   noise: 0.021
# Iter 44/100 - Loss: -0.429   lengthscale: 2.965   noise: 0.020
# Iter 45/100 - Loss: -0.425   lengthscale: 2.968   noise: 0.019
# Iter 46/100 - Loss: -0.422   lengthscale: 2.968   noise: 0.019
# Iter 47/100 - Loss: -0.420   lengthscale: 2.964   noise: 0.018
# Iter 48/100 - Loss: -0.418   lengthscale: 2.958   noise: 0.018
# Iter 49/100 - Loss: -0.418   lengthscale: 2.950   noise: 0.018
# Iter 50/100 - Loss: -0.418   lengthscale: 2.939   noise: 0.018
# Iter 51/100 - Loss: -0.419   lengthscale: 2.926   noise: 0.018
# Iter 52/100 - Loss: -0.420   lengthscale: 2.910   noise: 0.018
# Iter 53/100 - Loss: -0.423   lengthscale: 2.894   noise: 0.019
# Iter 54/100 - Loss: -0.425   lengthscale: 2.876   noise: 0.019
# Iter 55/100 - Loss: -0.428   lengthscale: 2.857   noise: 0.019
# Iter 56/100 - Loss: -0.430   lengthscale: 2.838   noise: 0.020
# Iter 57/100 - Loss: -0.432   lengthscale: 2.818   noise: 0.020
# Iter 58/100 - Loss: -0.435   lengthscale: 2.799   noise: 0.021
# Iter 59/100 - Loss: -0.436   lengthscale: 2.780   noise: 0.021
# Iter 60/100 - Loss: -0.438   lengthscale: 2.762   noise: 0.022
# Iter 61/100 - Loss: -0.439   lengthscale: 2.745   noise: 0.022
# Iter 62/100 - Loss: -0.439   lengthscale: 2.729   noise: 0.023
# Iter 63/100 - Loss: -0.440   lengthscale: 2.715   noise: 0.023
# Iter 64/100 - Loss: -0.440   lengthscale: 2.701   noise: 0.024
# Iter 65/100 - Loss: -0.440   lengthscale: 2.690   noise: 0.024
# Iter 66/100 - Loss: -0.439   lengthscale: 2.680   noise: 0.025
# Iter 67/100 - Loss: -0.439   lengthscale: 2.671   noise: 0.025
# Iter 68/100 - Loss: -0.439   lengthscale: 2.664   noise: 0.025
# Iter 69/100 - Loss: -0.439   lengthscale: 2.657   noise: 0.025
# Iter 70/100 - Loss: -0.439   lengthscale: 2.652   noise: 0.026
# Iter 71/100 - Loss: -0.439   lengthscale: 2.647   noise: 0.026
# Iter 72/100 - Loss: -0.439   lengthscale: 2.643   noise: 0.026
# Iter 73/100 - Loss: -0.439   lengthscale: 2.638   noise: 0.026
# Iter 74/100 - Loss: -0.439   lengthscale: 2.633   noise: 0.026
# Iter 75/100 - Loss: -0.439   lengthscale: 2.627   noise: 0.026
# Iter 76/100 - Loss: -0.439   lengthscale: 2.621   noise: 0.026
# Iter 77/100 - Loss: -0.439   lengthscale: 2.614   noise: 0.026
# Iter 78/100 - Loss: -0.439   lengthscale: 2.605   noise: 0.025
# Iter 79/100 - Loss: -0.440   lengthscale: 2.595   noise: 0.025
# Iter 80/100 - Loss: -0.440   lengthscale: 2.584   noise: 0.025
# Iter 81/100 - Loss: -0.440   lengthscale: 2.572   noise: 0.025
# Iter 82/100 - Loss: -0.440   lengthscale: 2.558   noise: 0.025
# Iter 83/100 - Loss: -0.440   lengthscale: 2.542   noise: 0.025
# Iter 84/100 - Loss: -0.441   lengthscale: 2.525   noise: 0.024
# Iter 85/100 - Loss: -0.441   lengthscale: 2.507   noise: 0.024
# Iter 86/100 - Loss: -0.441   lengthscale: 2.487   noise: 0.024
# Iter 87/100 - Loss: -0.441   lengthscale: 2.466   noise: 0.024
# Iter 88/100 - Loss: -0.441   lengthscale: 2.444   noise: 0.024
# Iter 89/100 - Loss: -0.441   lengthscale: 2.421   noise: 0.024
# Iter 90/100 - Loss: -0.441   lengthscale: 2.396   noise: 0.023
# Iter 91/100 - Loss: -0.441   lengthscale: 2.371   noise: 0.023
# Iter 92/100 - Loss: -0.441   lengthscale: 2.344   noise: 0.023
# Iter 93/100 - Loss: -0.441   lengthscale: 2.316   noise: 0.023
# Iter 94/100 - Loss: -0.441   lengthscale: 2.288   noise: 0.023
# Iter 95/100 - Loss: -0.441   lengthscale: 2.258   noise: 0.023
# Iter 96/100 - Loss: -0.441   lengthscale: 2.228   noise: 0.023
# Iter 97/100 - Loss: -0.441   lengthscale: 2.197   noise: 0.023
# Iter 98/100 - Loss: -0.441   lengthscale: 2.166   noise: 0.023
# Iter 99/100 - Loss: -0.441   lengthscale: 2.133   noise: 0.023
# Iter 100/100 - Loss: -0.441   lengthscale: 2.100   noise: 0.023
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.772   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.736   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.699   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.661   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.623   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.584   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.545   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.505   lengthscale: 1.098   noise: 0.403
# Iter 9/100 - Loss: 0.465   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.424   lengthscale: 1.230   noise: 0.340
# Iter 11/100 - Loss: 0.382   lengthscale: 1.297   noise: 0.312
# Iter 12/100 - Loss: 0.340   lengthscale: 1.366   noise: 0.286
# Iter 13/100 - Loss: 0.298   lengthscale: 1.436   noise: 0.262
# Iter 14/100 - Loss: 0.256   lengthscale: 1.506   noise: 0.239
# Iter 15/100 - Loss: 0.213   lengthscale: 1.577   noise: 0.218
# Iter 16/100 - Loss: 0.170   lengthscale: 1.648   noise: 0.199
# Iter 17/100 - Loss: 0.127   lengthscale: 1.719   noise: 0.181
# Iter 18/100 - Loss: 0.085   lengthscale: 1.790   noise: 0.165
# Iter 19/100 - Loss: 0.042   lengthscale: 1.861   noise: 0.150
# Iter 20/100 - Loss: -0.001   lengthscale: 1.931   noise: 0.137
# Iter 21/100 - Loss: -0.043   lengthscale: 2.002   noise: 0.124
# Iter 22/100 - Loss: -0.085   lengthscale: 2.072   noise: 0.113
# Iter 23/100 - Loss: -0.127   lengthscale: 2.141   noise: 0.102
# Iter 24/100 - Loss: -0.167   lengthscale: 2.209   noise: 0.093
# Iter 25/100 - Loss: -0.208   lengthscale: 2.277   noise: 0.084
# Iter 26/100 - Loss: -0.247   lengthscale: 2.344   noise: 0.076
# Iter 27/100 - Loss: -0.285   lengthscale: 2.410   noise: 0.069
# Iter 28/100 - Loss: -0.322   lengthscale: 2.476   noise: 0.063
# Iter 29/100 - Loss: -0.358   lengthscale: 2.540   noise: 0.057
# Iter 30/100 - Loss: -0.392   lengthscale: 2.603   noise: 0.052
# Iter 31/100 - Loss: -0.425   lengthscale: 2.666   noise: 0.047
# Iter 32/100 - Loss: -0.456   lengthscale: 2.727   noise: 0.043
# Iter 33/100 - Loss: -0.485   lengthscale: 2.787   noise: 0.039
# Iter 34/100 - Loss: -0.512   lengthscale: 2.846   noise: 0.036
# Iter 35/100 - Loss: -0.536   lengthscale: 2.904   noise: 0.033
# Iter 36/100 - Loss: -0.558   lengthscale: 2.961   noise: 0.030
# Iter 37/100 - Loss: -0.578   lengthscale: 3.017   noise: 0.027
# Iter 38/100 - Loss: -0.595   lengthscale: 3.072   noise: 0.025
# Iter 39/100 - Loss: -0.609   lengthscale: 3.125   noise: 0.023
# Iter 40/100 - Loss: -0.621   lengthscale: 3.177   noise: 0.021
# Iter 41/100 - Loss: -0.630   lengthscale: 3.229   noise: 0.020
# Iter 42/100 - Loss: -0.636   lengthscale: 3.278   noise: 0.018
# Iter 43/100 - Loss: -0.640   lengthscale: 3.327   noise: 0.017
# Iter 44/100 - Loss: -0.643   lengthscale: 3.374   noise: 0.016
# Iter 45/100 - Loss: -0.643   lengthscale: 3.419   noise: 0.015
# Iter 46/100 - Loss: -0.642   lengthscale: 3.463   noise: 0.015
# Iter 47/100 - Loss: -0.640   lengthscale: 3.504   noise: 0.014
# Iter 48/100 - Loss: -0.638   lengthscale: 3.544   noise: 0.013
# Iter 49/100 - Loss: -0.635   lengthscale: 3.582   noise: 0.013
# Iter 50/100 - Loss: -0.632   lengthscale: 3.617   noise: 0.013
# Iter 51/100 - Loss: -0.629   lengthscale: 3.650   noise: 0.012
# Iter 52/100 - Loss: -0.627   lengthscale: 3.680   noise: 0.012
# Iter 53/100 - Loss: -0.626   lengthscale: 3.707   noise: 0.012
# Iter 54/100 - Loss: -0.626   lengthscale: 3.731   noise: 0.012
# Iter 55/100 - Loss: -0.626   lengthscale: 3.751   noise: 0.012
# Iter 56/100 - Loss: -0.627   lengthscale: 3.768   noise: 0.012
# Iter 57/100 - Loss: -0.628   lengthscale: 3.781   noise: 0.012
# Iter 58/100 - Loss: -0.630   lengthscale: 3.791   noise: 0.013
# Iter 59/100 - Loss: -0.633   lengthscale: 3.799   noise: 0.013
# Iter 60/100 - Loss: -0.635   lengthscale: 3.804   noise: 0.013
# Iter 61/100 - Loss: -0.637   lengthscale: 3.808   noise: 0.013
# Iter 62/100 - Loss: -0.639   lengthscale: 3.810   noise: 0.014
# Iter 63/100 - Loss: -0.641   lengthscale: 3.812   noise: 0.014
# Iter 64/100 - Loss: -0.643   lengthscale: 3.813   noise: 0.014
# Iter 65/100 - Loss: -0.644   lengthscale: 3.814   noise: 0.015
# Iter 66/100 - Loss: -0.645   lengthscale: 3.814   noise: 0.015
# Iter 67/100 - Loss: -0.645   lengthscale: 3.815   noise: 0.015
# Iter 68/100 - Loss: -0.646   lengthscale: 3.816   noise: 0.015
# Iter 69/100 - Loss: -0.646   lengthscale: 3.818   noise: 0.016
# Iter 70/100 - Loss: -0.646   lengthscale: 3.820   noise: 0.016
# Iter 71/100 - Loss: -0.646   lengthscale: 3.822   noise: 0.016
# Iter 72/100 - Loss: -0.645   lengthscale: 3.825   noise: 0.017
# Iter 73/100 - Loss: -0.645   lengthscale: 3.828   noise: 0.017
# Iter 74/100 - Loss: -0.645   lengthscale: 3.831   noise: 0.017
# Iter 75/100 - Loss: -0.645   lengthscale: 3.835   noise: 0.017
# Iter 76/100 - Loss: -0.645   lengthscale: 3.838   noise: 0.017
# Iter 77/100 - Loss: -0.645   lengthscale: 3.842   noise: 0.017
# Iter 78/100 - Loss: -0.645   lengthscale: 3.846   noise: 0.017
# Iter 79/100 - Loss: -0.645   lengthscale: 3.850   noise: 0.017
# Iter 80/100 - Loss: -0.645   lengthscale: 3.854   noise: 0.017
# Iter 81/100 - Loss: -0.645   lengthscale: 3.857   noise: 0.017
# Iter 82/100 - Loss: -0.645   lengthscale: 3.861   noise: 0.017
# Iter 83/100 - Loss: -0.645   lengthscale: 3.864   noise: 0.017
# Iter 84/100 - Loss: -0.645   lengthscale: 3.867   noise: 0.017
# Iter 85/100 - Loss: -0.646   lengthscale: 3.870   noise: 0.017
# Iter 86/100 - Loss: -0.646   lengthscale: 3.872   noise: 0.017
# Iter 87/100 - Loss: -0.646   lengthscale: 3.874   noise: 0.017
# Iter 88/100 - Loss: -0.646   lengthscale: 3.875   noise: 0.016
# Iter 89/100 - Loss: -0.646   lengthscale: 3.876   noise: 0.016
# Iter 90/100 - Loss: -0.646   lengthscale: 3.877   noise: 0.016
# Iter 91/100 - Loss: -0.646   lengthscale: 3.877   noise: 0.016
# Iter 92/100 - Loss: -0.646   lengthscale: 3.877   noise: 0.016
# Iter 93/100 - Loss: -0.646   lengthscale: 3.876   noise: 0.016
# Iter 94/100 - Loss: -0.646   lengthscale: 3.874   noise: 0.016
# Iter 95/100 - Loss: -0.646   lengthscale: 3.872   noise: 0.016
# Iter 96/100 - Loss: -0.646   lengthscale: 3.870   noise: 0.016
# Iter 97/100 - Loss: -0.646   lengthscale: 3.867   noise: 0.016
# Iter 98/100 - Loss: -0.646   lengthscale: 3.863   noise: 0.016
# Iter 99/100 - Loss: -0.646   lengthscale: 3.859   noise: 0.015
# Iter 100/100 - Loss: -0.646   lengthscale: 3.855   noise: 0.015
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.773   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.737   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.700   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.663   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.625   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.586   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.547   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.507   lengthscale: 1.098   noise: 0.403
# Iter 9/100 - Loss: 0.467   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.426   lengthscale: 1.230   noise: 0.340
# Iter 11/100 - Loss: 0.385   lengthscale: 1.298   noise: 0.312
# Iter 12/100 - Loss: 0.343   lengthscale: 1.367   noise: 0.286
# Iter 13/100 - Loss: 0.301   lengthscale: 1.437   noise: 0.262
# Iter 14/100 - Loss: 0.259   lengthscale: 1.507   noise: 0.239
# Iter 15/100 - Loss: 0.217   lengthscale: 1.578   noise: 0.218
# Iter 16/100 - Loss: 0.174   lengthscale: 1.649   noise: 0.199
# Iter 17/100 - Loss: 0.132   lengthscale: 1.720   noise: 0.181
# Iter 18/100 - Loss: 0.089   lengthscale: 1.791   noise: 0.165
# Iter 19/100 - Loss: 0.047   lengthscale: 1.863   noise: 0.150
# Iter 20/100 - Loss: 0.005   lengthscale: 1.933   noise: 0.137
# Iter 21/100 - Loss: -0.037   lengthscale: 2.004   noise: 0.124
# Iter 22/100 - Loss: -0.078   lengthscale: 2.074   noise: 0.113
# Iter 23/100 - Loss: -0.119   lengthscale: 2.143   noise: 0.102
# Iter 24/100 - Loss: -0.159   lengthscale: 2.212   noise: 0.093
# Iter 25/100 - Loss: -0.198   lengthscale: 2.280   noise: 0.084
# Iter 26/100 - Loss: -0.236   lengthscale: 2.347   noise: 0.077
# Iter 27/100 - Loss: -0.274   lengthscale: 2.412   noise: 0.070
# Iter 28/100 - Loss: -0.309   lengthscale: 2.477   noise: 0.063
# Iter 29/100 - Loss: -0.344   lengthscale: 2.541   noise: 0.057
# Iter 30/100 - Loss: -0.377   lengthscale: 2.604   noise: 0.052
# Iter 31/100 - Loss: -0.408   lengthscale: 2.665   noise: 0.047
# Iter 32/100 - Loss: -0.437   lengthscale: 2.726   noise: 0.043
# Iter 33/100 - Loss: -0.464   lengthscale: 2.785   noise: 0.039
# Iter 34/100 - Loss: -0.489   lengthscale: 2.843   noise: 0.036
# Iter 35/100 - Loss: -0.511   lengthscale: 2.900   noise: 0.033
# Iter 36/100 - Loss: -0.531   lengthscale: 2.956   noise: 0.030
# Iter 37/100 - Loss: -0.548   lengthscale: 3.011   noise: 0.028
# Iter 38/100 - Loss: -0.563   lengthscale: 3.064   noise: 0.025
# Iter 39/100 - Loss: -0.575   lengthscale: 3.116   noise: 0.024
# Iter 40/100 - Loss: -0.584   lengthscale: 3.167   noise: 0.022
# Iter 41/100 - Loss: -0.591   lengthscale: 3.217   noise: 0.020
# Iter 42/100 - Loss: -0.595   lengthscale: 3.265   noise: 0.019
# Iter 43/100 - Loss: -0.598   lengthscale: 3.313   noise: 0.018
# Iter 44/100 - Loss: -0.598   lengthscale: 3.359   noise: 0.017
# Iter 45/100 - Loss: -0.597   lengthscale: 3.404   noise: 0.016
# Iter 46/100 - Loss: -0.595   lengthscale: 3.448   noise: 0.015
# Iter 47/100 - Loss: -0.592   lengthscale: 3.490   noise: 0.015
# Iter 48/100 - Loss: -0.589   lengthscale: 3.532   noise: 0.014
# Iter 49/100 - Loss: -0.587   lengthscale: 3.573   noise: 0.014
# Iter 50/100 - Loss: -0.584   lengthscale: 3.613   noise: 0.014
# Iter 51/100 - Loss: -0.583   lengthscale: 3.651   noise: 0.013
# Iter 52/100 - Loss: -0.582   lengthscale: 3.689   noise: 0.013
# Iter 53/100 - Loss: -0.581   lengthscale: 3.726   noise: 0.013
# Iter 54/100 - Loss: -0.582   lengthscale: 3.762   noise: 0.013
# Iter 55/100 - Loss: -0.583   lengthscale: 3.798   noise: 0.013
# Iter 56/100 - Loss: -0.585   lengthscale: 3.832   noise: 0.013
# Iter 57/100 - Loss: -0.587   lengthscale: 3.866   noise: 0.014
# Iter 58/100 - Loss: -0.590   lengthscale: 3.898   noise: 0.014
# Iter 59/100 - Loss: -0.592   lengthscale: 3.930   noise: 0.014
# Iter 60/100 - Loss: -0.595   lengthscale: 3.961   noise: 0.014
# Iter 61/100 - Loss: -0.597   lengthscale: 3.991   noise: 0.015
# Iter 62/100 - Loss: -0.599   lengthscale: 4.021   noise: 0.015
# Iter 63/100 - Loss: -0.601   lengthscale: 4.049   noise: 0.016
# Iter 64/100 - Loss: -0.602   lengthscale: 4.077   noise: 0.016
# Iter 65/100 - Loss: -0.603   lengthscale: 4.103   noise: 0.016
# Iter 66/100 - Loss: -0.604   lengthscale: 4.129   noise: 0.017
# Iter 67/100 - Loss: -0.604   lengthscale: 4.153   noise: 0.017
# Iter 68/100 - Loss: -0.604   lengthscale: 4.177   noise: 0.017
# Iter 69/100 - Loss: -0.605   lengthscale: 4.200   noise: 0.018
# Iter 70/100 - Loss: -0.604   lengthscale: 4.221   noise: 0.018
# Iter 71/100 - Loss: -0.604   lengthscale: 4.242   noise: 0.018
# Iter 72/100 - Loss: -0.604   lengthscale: 4.262   noise: 0.018
# Iter 73/100 - Loss: -0.604   lengthscale: 4.281   noise: 0.018
# Iter 74/100 - Loss: -0.604   lengthscale: 4.298   noise: 0.019
# Iter 75/100 - Loss: -0.604   lengthscale: 4.315   noise: 0.019
# Iter 76/100 - Loss: -0.604   lengthscale: 4.331   noise: 0.019
# Iter 77/100 - Loss: -0.604   lengthscale: 4.346   noise: 0.019
# Iter 78/100 - Loss: -0.604   lengthscale: 4.360   noise: 0.019
# Iter 79/100 - Loss: -0.604   lengthscale: 4.373   noise: 0.019
# Iter 80/100 - Loss: -0.604   lengthscale: 4.385   noise: 0.019
# Iter 81/100 - Loss: -0.604   lengthscale: 4.397   noise: 0.019
# Iter 82/100 - Loss: -0.604   lengthscale: 4.407   noise: 0.019
# Iter 83/100 - Loss: -0.605   lengthscale: 4.417   noise: 0.018
# Iter 84/100 - Loss: -0.605   lengthscale: 4.426   noise: 0.018
# Iter 85/100 - Loss: -0.605   lengthscale: 4.435   noise: 0.018
# Iter 86/100 - Loss: -0.605   lengthscale: 4.442   noise: 0.018
# Iter 87/100 - Loss: -0.605   lengthscale: 4.449   noise: 0.018
# Iter 88/100 - Loss: -0.606   lengthscale: 4.455   noise: 0.018
# Iter 89/100 - Loss: -0.606   lengthscale: 4.461   noise: 0.018
# Iter 90/100 - Loss: -0.606   lengthscale: 4.466   noise: 0.018
# Iter 91/100 - Loss: -0.606   lengthscale: 4.470   noise: 0.017
# Iter 92/100 - Loss: -0.606   lengthscale: 4.474   noise: 0.017
# Iter 93/100 - Loss: -0.606   lengthscale: 4.477   noise: 0.017
# Iter 94/100 - Loss: -0.606   lengthscale: 4.479   noise: 0.017
# Iter 95/100 - Loss: -0.606   lengthscale: 4.481   noise: 0.017
# Iter 96/100 - Loss: -0.606   lengthscale: 4.483   noise: 0.017
# Iter 97/100 - Loss: -0.606   lengthscale: 4.484   noise: 0.017
# Iter 98/100 - Loss: -0.606   lengthscale: 4.484   noise: 0.017
# Iter 99/100 - Loss: -0.606   lengthscale: 4.484   noise: 0.017
# Iter 100/100 - Loss: -0.606   lengthscale: 4.484   noise: 0.017
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.776   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.740   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.703   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.666   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.628   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.590   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.551   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.511   lengthscale: 1.098   noise: 0.403
# Iter 9/100 - Loss: 0.471   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.431   lengthscale: 1.230   noise: 0.340
# Iter 11/100 - Loss: 0.390   lengthscale: 1.298   noise: 0.312
# Iter 12/100 - Loss: 0.349   lengthscale: 1.367   noise: 0.286
# Iter 13/100 - Loss: 0.307   lengthscale: 1.437   noise: 0.262
# Iter 14/100 - Loss: 0.266   lengthscale: 1.508   noise: 0.239
# Iter 15/100 - Loss: 0.224   lengthscale: 1.579   noise: 0.218
# Iter 16/100 - Loss: 0.183   lengthscale: 1.650   noise: 0.199
# Iter 17/100 - Loss: 0.141   lengthscale: 1.722   noise: 0.182
# Iter 18/100 - Loss: 0.099   lengthscale: 1.793   noise: 0.165
# Iter 19/100 - Loss: 0.058   lengthscale: 1.865   noise: 0.150
# Iter 20/100 - Loss: 0.017   lengthscale: 1.936   noise: 0.137
# Iter 21/100 - Loss: -0.023   lengthscale: 2.007   noise: 0.124
# Iter 22/100 - Loss: -0.063   lengthscale: 2.078   noise: 0.113
# Iter 23/100 - Loss: -0.102   lengthscale: 2.148   noise: 0.103
# Iter 24/100 - Loss: -0.140   lengthscale: 2.218   noise: 0.093
# Iter 25/100 - Loss: -0.178   lengthscale: 2.287   noise: 0.085
# Iter 26/100 - Loss: -0.214   lengthscale: 2.355   noise: 0.077
# Iter 27/100 - Loss: -0.249   lengthscale: 2.421   noise: 0.070
# Iter 28/100 - Loss: -0.283   lengthscale: 2.487   noise: 0.064
# Iter 29/100 - Loss: -0.315   lengthscale: 2.551   noise: 0.058
# Iter 30/100 - Loss: -0.345   lengthscale: 2.613   noise: 0.053
# Iter 31/100 - Loss: -0.373   lengthscale: 2.673   noise: 0.048
# Iter 32/100 - Loss: -0.399   lengthscale: 2.731   noise: 0.044
# Iter 33/100 - Loss: -0.422   lengthscale: 2.787   noise: 0.040
# Iter 34/100 - Loss: -0.443   lengthscale: 2.840   noise: 0.037
# Iter 35/100 - Loss: -0.461   lengthscale: 2.891   noise: 0.034
# Iter 36/100 - Loss: -0.477   lengthscale: 2.939   noise: 0.031
# Iter 37/100 - Loss: -0.489   lengthscale: 2.983   noise: 0.029
# Iter 38/100 - Loss: -0.499   lengthscale: 3.025   noise: 0.026
# Iter 39/100 - Loss: -0.506   lengthscale: 3.064   noise: 0.025
# Iter 40/100 - Loss: -0.511   lengthscale: 3.099   noise: 0.023
# Iter 41/100 - Loss: -0.513   lengthscale: 3.130   noise: 0.021
# Iter 42/100 - Loss: -0.514   lengthscale: 3.158   noise: 0.020
# Iter 43/100 - Loss: -0.512   lengthscale: 3.182   noise: 0.019
# Iter 44/100 - Loss: -0.510   lengthscale: 3.202   noise: 0.018
# Iter 45/100 - Loss: -0.507   lengthscale: 3.218   noise: 0.018
# Iter 46/100 - Loss: -0.504   lengthscale: 3.231   noise: 0.017
# Iter 47/100 - Loss: -0.500   lengthscale: 3.240   noise: 0.016
# Iter 48/100 - Loss: -0.498   lengthscale: 3.246   noise: 0.016
# Iter 49/100 - Loss: -0.495   lengthscale: 3.249   noise: 0.016
# Iter 50/100 - Loss: -0.494   lengthscale: 3.249   noise: 0.016
# Iter 51/100 - Loss: -0.494   lengthscale: 3.247   noise: 0.016
# Iter 52/100 - Loss: -0.494   lengthscale: 3.242   noise: 0.016
# Iter 53/100 - Loss: -0.495   lengthscale: 3.236   noise: 0.016
# Iter 54/100 - Loss: -0.497   lengthscale: 3.229   noise: 0.016
# Iter 55/100 - Loss: -0.499   lengthscale: 3.220   noise: 0.016
# Iter 56/100 - Loss: -0.501   lengthscale: 3.212   noise: 0.016
# Iter 57/100 - Loss: -0.504   lengthscale: 3.202   noise: 0.017
# Iter 58/100 - Loss: -0.506   lengthscale: 3.194   noise: 0.017
# Iter 59/100 - Loss: -0.508   lengthscale: 3.185   noise: 0.018
# Iter 60/100 - Loss: -0.510   lengthscale: 3.177   noise: 0.018
# Iter 61/100 - Loss: -0.512   lengthscale: 3.171   noise: 0.018
# Iter 62/100 - Loss: -0.513   lengthscale: 3.165   noise: 0.019
# Iter 63/100 - Loss: -0.514   lengthscale: 3.161   noise: 0.019
# Iter 64/100 - Loss: -0.515   lengthscale: 3.158   noise: 0.020
# Iter 65/100 - Loss: -0.515   lengthscale: 3.156   noise: 0.020
# Iter 66/100 - Loss: -0.515   lengthscale: 3.155   noise: 0.021
# Iter 67/100 - Loss: -0.515   lengthscale: 3.156   noise: 0.021
# Iter 68/100 - Loss: -0.515   lengthscale: 3.158   noise: 0.021
# Iter 69/100 - Loss: -0.515   lengthscale: 3.161   noise: 0.022
# Iter 70/100 - Loss: -0.514   lengthscale: 3.165   noise: 0.022
# Iter 71/100 - Loss: -0.514   lengthscale: 3.169   noise: 0.022
# Iter 72/100 - Loss: -0.514   lengthscale: 3.175   noise: 0.022
# Iter 73/100 - Loss: -0.514   lengthscale: 3.180   noise: 0.022
# Iter 74/100 - Loss: -0.514   lengthscale: 3.186   noise: 0.022
# Iter 75/100 - Loss: -0.514   lengthscale: 3.192   noise: 0.022
# Iter 76/100 - Loss: -0.514   lengthscale: 3.198   noise: 0.022
# Iter 77/100 - Loss: -0.514   lengthscale: 3.204   noise: 0.022
# Iter 78/100 - Loss: -0.514   lengthscale: 3.210   noise: 0.022
# Iter 79/100 - Loss: -0.514   lengthscale: 3.215   noise: 0.022
# Iter 80/100 - Loss: -0.515   lengthscale: 3.220   noise: 0.022
# Iter 81/100 - Loss: -0.515   lengthscale: 3.225   noise: 0.022
# Iter 82/100 - Loss: -0.515   lengthscale: 3.229   noise: 0.022
# Iter 83/100 - Loss: -0.515   lengthscale: 3.233   noise: 0.022
# Iter 84/100 - Loss: -0.515   lengthscale: 3.236   noise: 0.021
# Iter 85/100 - Loss: -0.516   lengthscale: 3.239   noise: 0.021
# Iter 86/100 - Loss: -0.516   lengthscale: 3.241   noise: 0.021
# Iter 87/100 - Loss: -0.516   lengthscale: 3.243   noise: 0.021
# Iter 88/100 - Loss: -0.516   lengthscale: 3.246   noise: 0.021
# Iter 89/100 - Loss: -0.516   lengthscale: 3.248   noise: 0.021
# Iter 90/100 - Loss: -0.516   lengthscale: 3.250   noise: 0.020
# Iter 91/100 - Loss: -0.516   lengthscale: 3.252   noise: 0.020
# Iter 92/100 - Loss: -0.516   lengthscale: 3.254   noise: 0.020
# Iter 93/100 - Loss: -0.516   lengthscale: 3.257   noise: 0.020
# Iter 94/100 - Loss: -0.516   lengthscale: 3.260   noise: 0.020
# Iter 95/100 - Loss: -0.516   lengthscale: 3.264   noise: 0.020
# Iter 96/100 - Loss: -0.516   lengthscale: 3.268   noise: 0.020
# Iter 97/100 - Loss: -0.516   lengthscale: 3.273   noise: 0.020
# Iter 98/100 - Loss: -0.517   lengthscale: 3.278   noise: 0.020
# Iter 99/100 - Loss: -0.517   lengthscale: 3.284   noise: 0.020
# Iter 100/100 - Loss: -0.517   lengthscale: 3.291   noise: 0.020
# Planning to run on 1 GPUs.
# Iter 1/100 - Loss: 0.772   lengthscale: 0.693   noise: 0.693
# Iter 2/100 - Loss: 0.735   lengthscale: 0.744   noise: 0.644
# Iter 3/100 - Loss: 0.698   lengthscale: 0.798   noise: 0.598
# Iter 4/100 - Loss: 0.661   lengthscale: 0.854   noise: 0.554
# Iter 5/100 - Loss: 0.622   lengthscale: 0.912   noise: 0.513
# Iter 6/100 - Loss: 0.584   lengthscale: 0.972   noise: 0.474
# Iter 7/100 - Loss: 0.544   lengthscale: 1.034   noise: 0.437
# Iter 8/100 - Loss: 0.504   lengthscale: 1.098   noise: 0.403
# Iter 9/100 - Loss: 0.464   lengthscale: 1.163   noise: 0.370
# Iter 10/100 - Loss: 0.422   lengthscale: 1.230   noise: 0.340
# Iter 11/100 - Loss: 0.381   lengthscale: 1.297   noise: 0.312
# Iter 12/100 - Loss: 0.339   lengthscale: 1.366   noise: 0.286
# Iter 13/100 - Loss: 0.297   lengthscale: 1.435   noise: 0.262
# Iter 14/100 - Loss: 0.254   lengthscale: 1.505   noise: 0.239
# Iter 15/100 - Loss: 0.211   lengthscale: 1.576   noise: 0.218
# Iter 16/100 - Loss: 0.168   lengthscale: 1.646   noise: 0.199
# Iter 17/100 - Loss: 0.125   lengthscale: 1.717   noise: 0.181
# Iter 18/100 - Loss: 0.082   lengthscale: 1.787   noise: 0.165
# Iter 19/100 - Loss: 0.039   lengthscale: 1.857   noise: 0.150
# Iter 20/100 - Loss: -0.004   lengthscale: 1.927   noise: 0.137
# Iter 21/100 - Loss: -0.046   lengthscale: 1.996   noise: 0.124
# Iter 22/100 - Loss: -0.088   lengthscale: 2.064   noise: 0.113
# Iter 23/100 - Loss: -0.130   lengthscale: 2.132   noise: 0.102
# Iter 24/100 - Loss: -0.171   lengthscale: 2.199   noise: 0.093
# Iter 25/100 - Loss: -0.212   lengthscale: 2.265   noise: 0.084
# Iter 26/100 - Loss: -0.252   lengthscale: 2.330   noise: 0.076
# Iter 27/100 - Loss: -0.290   lengthscale: 2.394   noise: 0.069
# Iter 28/100 - Loss: -0.328   lengthscale: 2.456   noise: 0.063
# Iter 29/100 - Loss: -0.364   lengthscale: 2.518   noise: 0.057
# Iter 30/100 - Loss: -0.399   lengthscale: 2.578   noise: 0.052
# Iter 31/100 - Loss: -0.433   lengthscale: 2.637   noise: 0.047
# Iter 32/100 - Loss: -0.464   lengthscale: 2.695   noise: 0.043
# Iter 33/100 - Loss: -0.494   lengthscale: 2.751   noise: 0.039
# Iter 34/100 - Loss: -0.522   lengthscale: 2.806   noise: 0.035
# Iter 35/100 - Loss: -0.547   lengthscale: 2.859   noise: 0.032
# Iter 36/100 - Loss: -0.570   lengthscale: 2.911   noise: 0.030
# Iter 37/100 - Loss: -0.591   lengthscale: 2.961   noise: 0.027
# Iter 38/100 - Loss: -0.609   lengthscale: 3.010   noise: 0.025
# Iter 39/100 - Loss: -0.624   lengthscale: 3.057   noise: 0.023
# Iter 40/100 - Loss: -0.637   lengthscale: 3.103   noise: 0.021
# Iter 41/100 - Loss: -0.647   lengthscale: 3.146   noise: 0.020
# Iter 42/100 - Loss: -0.655   lengthscale: 3.189   noise: 0.018
# Iter 43/100 - Loss: -0.660   lengthscale: 3.229   noise: 0.017
# Iter 44/100 - Loss: -0.663   lengthscale: 3.268   noise: 0.016
# Iter 45/100 - Loss: -0.663   lengthscale: 3.305   noise: 0.015
# Iter 46/100 - Loss: -0.663   lengthscale: 3.341   noise: 0.014
# Iter 47/100 - Loss: -0.661   lengthscale: 3.374   noise: 0.014
# Iter 48/100 - Loss: -0.659   lengthscale: 3.407   noise: 0.013
# Iter 49/100 - Loss: -0.656   lengthscale: 3.437   noise: 0.013
# Iter 50/100 - Loss: -0.653   lengthscale: 3.466   noise: 0.012
# Iter 51/100 - Loss: -0.650   lengthscale: 3.494   noise: 0.012
# Iter 52/100 - Loss: -0.648   lengthscale: 3.520   noise: 0.012
# Iter 53/100 - Loss: -0.646   lengthscale: 3.545   noise: 0.012
# Iter 54/100 - Loss: -0.646   lengthscale: 3.569   noise: 0.012
# Iter 55/100 - Loss: -0.646   lengthscale: 3.591   noise: 0.012
# Iter 56/100 - Loss: -0.647   lengthscale: 3.612   noise: 0.012
# Iter 57/100 - Loss: -0.648   lengthscale: 3.633   noise: 0.012
# Iter 58/100 - Loss: -0.650   lengthscale: 3.652   noise: 0.012
# Iter 59/100 - Loss: -0.652   lengthscale: 3.671   noise: 0.012
# Iter 60/100 - Loss: -0.655   lengthscale: 3.688   noise: 0.012
# Iter 61/100 - Loss: -0.657   lengthscale: 3.705   noise: 0.013
# Iter 62/100 - Loss: -0.659   lengthscale: 3.721   noise: 0.013
# Iter 63/100 - Loss: -0.661   lengthscale: 3.736   noise: 0.013
# Iter 64/100 - Loss: -0.663   lengthscale: 3.751   noise: 0.013
# Iter 65/100 - Loss: -0.664   lengthscale: 3.765   noise: 0.014
# Iter 66/100 - Loss: -0.666   lengthscale: 3.778   noise: 0.014
# Iter 67/100 - Loss: -0.666   lengthscale: 3.791   noise: 0.014
# Iter 68/100 - Loss: -0.667   lengthscale: 3.803   noise: 0.015
# Iter 69/100 - Loss: -0.667   lengthscale: 3.814   noise: 0.015
# Iter 70/100 - Loss: -0.667   lengthscale: 3.826   noise: 0.015
# Iter 71/100 - Loss: -0.667   lengthscale: 3.836   noise: 0.016
# Iter 72/100 - Loss: -0.668   lengthscale: 3.847   noise: 0.016
# Iter 73/100 - Loss: -0.670   lengthscale: 3.858   noise: 0.016
# Iter 74/100 - Loss: -0.673   lengthscale: 3.867   noise: 0.016
# Iter 75/100 - Loss: -0.675   lengthscale: 3.873   noise: 0.016
# Iter 76/100 - Loss: -0.677   lengthscale: 3.875   noise: 0.016
# Iter 77/100 - Loss: -0.677   lengthscale: 3.872   noise: 0.016
# Iter 78/100 - Loss: -0.677   lengthscale: 3.865   noise: 0.016
# Iter 79/100 - Loss: -0.677   lengthscale: 3.854   noise: 0.016
# Iter 80/100 - Loss: -0.677   lengthscale: 3.839   noise: 0.016
# Iter 81/100 - Loss: -0.677   lengthscale: 3.820   noise: 0.016
# Iter 82/100 - Loss: -0.677   lengthscale: 3.797   noise: 0.016
# Iter 83/100 - Loss: -0.677   lengthscale: 3.771   noise: 0.016
# Iter 84/100 - Loss: -0.677   lengthscale: 3.742   noise: 0.016
# Iter 85/100 - Loss: -0.678   lengthscale: 3.709   noise: 0.016
# Iter 86/100 - Loss: -0.678   lengthscale: 3.673   noise: 0.016
# Iter 87/100 - Loss: -0.679   lengthscale: 3.635   noise: 0.016
# Iter 88/100 - Loss: -0.679   lengthscale: 3.594   noise: 0.015
# Iter 89/100 - Loss: -0.680   lengthscale: 3.552   noise: 0.015
# Iter 90/100 - Loss: -0.680   lengthscale: 3.508   noise: 0.015
# Iter 91/100 - Loss: -0.680   lengthscale: 3.462   noise: 0.015
# Iter 92/100 - Loss: -0.681   lengthscale: 3.416   noise: 0.015
# Iter 93/100 - Loss: -0.681   lengthscale: 3.369   noise: 0.015
# Iter 94/100 - Loss: -0.681   lengthscale: 3.322   noise: 0.015
# Iter 95/100 - Loss: -0.682   lengthscale: 3.274   noise: 0.015
# Iter 96/100 - Loss: -0.682   lengthscale: 3.228   noise: 0.014
# Iter 97/100 - Loss: -0.682   lengthscale: 3.181   noise: 0.014
# Iter 98/100 - Loss: -0.682   lengthscale: 3.136   noise: 0.014
# Iter 99/100 - Loss: -0.682   lengthscale: 3.092   noise: 0.014
# Iter 100/100 - Loss: -0.682   lengthscale: 3.050   noise: 0.014

# %% [markdown]
# nnn= 'SOF_results_Symmetric.csv'
# df_tmp = pd.read_csv(nnn)
# #df_tmp = df_tmp.drop(columns=["Unnamed: 0"])
# df_tmp['target']="STEAK"
# df_tmp.to_csv(nnn, index=False)

# %%
df_plot = df_res
#df_plot = pd.read_csv('res_data/gp_all-paste.csv')
df_plot = df_plot[~(df_plot.type.isin(["rf_rf", "rf_grf", "rf_oracle"]))]
#df_plot = df_plot[~(df_plot.type.isin(["rf_approx_risk", "rf_approx_sol", "oracle"]))]
#df_plot = df_plot[~(df_plot.type.isin(["saa", "rf"]))]
sns.set(rc={'figure.figsize':(15,15)})
sns.set_style('whitegrid')
sns.relplot(data=df_plot, x="cu", y="cost",col_wrap=3,facet_kws={'sharey':False},
    col="target", hue="type",kind="line", aspect=1, height=4);

# %% [markdown]
# ## Visualize

# %%
test_df = load_yaz(encode_date_features=False, include_prod=[target]).frame.iloc[n_train:,:].copy()
test_df['mean_pred'] = nv_means_unscaled
test_df['std'] = nv_sigma_unscaled

# %%
g = sns.catplot(x="WEEKDAY", y="STEAK",
                col="MONTH",# hue="MONTH",
                aspect=.8,
                data=test_df, kind="box");

# %%
g = sns.catplot(x="WEEKDAY", y="mean_pred",
                col="MONTH",# hue="MONTH",
                aspect=.8,
                data=test_df, kind="box");

# %%
g = sns.catplot(x="WEEKDAY", y="std",
                col="MONTH",# hue="MONTH",
                aspect=.8,
                data=test_df, kind="box");

# %% [markdown]
# ## Plot Space

# %%
f0 = [torch.linspace(0, 1, 200) for i in range(1)]
fx = torch.linspace(1,1, 200) #temp
fn = [torch.linspace(0, 1, 200) for i in range(5)]#[torch.linspace(0.5, 0.5, 200) for i in range(2)]

# %%
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    #test_x = torch.linspace(0, 1, 51)
    sample_x = torch.stack([*f0,fx,*fn] , axis=-1).cuda()
    observed_pred = likelihood(model(sample_x))

# %%
feature_idx=2
with torch.no_grad():
    # Initialize plot
    f, ax = plt.subplots(1, 1, figsize=(15, 15))

    # Get upper and lower confidence bounds
    lower, upper = observed_pred.confidence_region()
    # Plot training data as black stars
    #ax.plot(train_x[:,feature_idx].cpu().numpy(), train_y.cpu().numpy(), 'k*')
    #ax.plot(sample_x[:,feature_idx].cpu().numpy(), y_samples.cpu().numpy(), lw=1)
    # Plot predictive means as blue line
    ax.plot(fx.numpy(), observed_pred.mean.cpu().numpy(), 'b')
    ax.plot(sample_x[:,feature_idx].cpu().numpy(), observed_pred.mean.cpu().numpy(), 'b')
    # Shade between the lower and upper confidence bounds
    ax.fill_between(sample_x[:,feature_idx].cpu().numpy(), lower.cpu().numpy(), upper.cpu().numpy(), alpha=0.5)
    #ax.fill_between(sample_x[:,feature_idx].cpu().numpy(), lower.cpu().numpy(), upper.cpu().numpy(), alpha=0.5)
    #ax.set_ylim([-3, 3])
    ax.legend(['Observed Data', 'Mean', 'Confidence'])
